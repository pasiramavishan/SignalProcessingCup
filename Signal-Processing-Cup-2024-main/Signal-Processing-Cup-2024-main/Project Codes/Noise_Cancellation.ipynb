# %% [markdown]
# Denoising

# %%
from scipy.io import wavfile 
import numpy as np 
from skimage.restoration import denoise_wavelet
import matplotlib.pyplot as plt
import soundfile as sf 
import os 
import scipy.io.wavfile as wavfile

# %%
#Appplying Wavelet transform to remove noise of 1 .wav file as an example 
#The example file = 00a49d6b07.wav
audio_file = os.path.join('ROBOVOX_SP_CUP_2024', 'data', 'single-channel', 'test', '00a49d6b07.wav')
Fs ,x = wavfile.read(audio_file)
x=x/max(x) #Normalizing

x_denoise = denoise_wavelet(x, method='VisuShrink', mode='soft', wavelet_levels=3, wavelet='sym8', rescale_sigma='True')

plt.figure(figsize=(20, 10), dpi=100)
plt.plot(x)
plt.plot(x_denoise)

# %%
#See the sizes of .wav files with noises and after removing noises
print(len(x_denoise))
print(len(x))
print("Sample rate = ", Fs)   #Sample rate
# Out:
# 98970
# 98970
# Sample rate =  16000

# %%
sf.write('denoise.wav', x_denoise, 16000)  #Writing denoise file into .wav form

# %%
#Let's plot fft of noise and denoise signals to compare
import numpy as np
from scipy.io import wavfile
import matplotlib.pyplot as plt

wav_file_1_path = audio_file
wav_file_2_path = "denoise.wav"

sample_rate_1, audio_data_1 = wavfile.read(wav_file_1_path)
sample_rate_2, audio_data_2 = wavfile.read(wav_file_2_path)

if sample_rate_1 != sample_rate_2:
    raise ValueError("Sample rates of both files should be equal!")

num_samples_1 = len(audio_data_1)
num_samples_2 = len(audio_data_2)

fft_data_1 = np.fft.fft(audio_data_1)
fft_data_2 = np.fft.fft(audio_data_2)

fft_frequencies = np.fft.fftfreq(num_samples_1, 1/sample_rate_1)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(fft_frequencies[:num_samples_1//2], np.abs(fft_data_1[:num_samples_1//2]))
plt.xlabel("Frequency (Hz)", fontsize=12)
plt.ylabel("FFT Amplitude", fontsize=12)
plt.title(f"FFT of Noise Audio", fontsize=14)
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(fft_frequencies[:num_samples_1//2], np.abs(fft_data_2[:num_samples_1//2]))
plt.xlabel("Frequency (Hz)", fontsize=12)
plt.ylabel("FFT Amplitude", fontsize=12)
plt.title(f"FFT Denoised Audio", fontsize=14)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
#We tried the code for a single .wav file 
#Now let's try it for a whole folder that includes many .wav files
folder_path = os.path.join('ROBOVOX_SP_CUP_2024', 'data', 'single-channel', 'test')  # Replace with the actual path to your folder

wav_file_paths = []

for root, directories, files in os.walk(folder_path):
    for file in files:
        if file.endswith(".wav"):
            file_path = os.path.join(root, file)
            wav_file_paths.append(file_path)

print(wav_file_paths)
# Out:
# ['ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0000f88619.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\000f6d0072.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\001dd0cb47.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\001f7db31a.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\001f86a5bf.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\002724b7ea.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0042734703.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00465a38b0.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\004adba134.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\005ae9cb2b.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\006a19dfc1.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\006ce8656f.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00806ad24b.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0086c2506c.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\008a2d1b07.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\008a7764f2.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0094b5dfc9.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\009ba16c1a.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00a49d6b07.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00a794c50e.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00a931d755.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00a99c3526.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00b83bd14a.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00b8e3ede3.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00b9eb2548.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00cb4de6c8.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00ceb6128b.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00d04a8940.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00d22594fc.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00db58f060.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00f0a14e19.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00f242e1eb.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00f2a5affd.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00f6eb9aee.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\00f9fa8a7d.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0108e00b88.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0114acfca1.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\01184d45ed.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\011b079e27.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\01228119f5.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0124c59443.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0125ca27d4.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\012800edf3.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\01310bec72.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0142035f16.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\014521e2a7.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0147917989.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0147bd89f3.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\014a9ec64b.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\01501469fe.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0155abee61.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0158a76985.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\015dff91cb.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\01647c610e.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0169f41593.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\017122cb08.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\0172890d96.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\01894d8589.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\test\\01896048c3.wav', 'ROBOVOX_SP_CUP_2024\\data\\single-channel\\te ...

# %%
print(len(wav_file_paths))  #Just to know the length
# Out:
# 10332

# %%
#Now let's wirte denoised .wav files in a new folder (New folder I named as denoise audio)
output_folder = os.path.join('ROBOVOX_SP_CUP_2024', 'data', 'single-channel', 'denoised-audio')

os.makedirs(output_folder, exist_ok=True)

for file_path in wav_file_paths:
    Fs, x = wavfile.read(file_path)
    #x = x / max(x)  # Normalize
    #I commented the above line because I did the normalization after removing noises here

    x_denoise = denoise_wavelet(x, method='VisuShrink', mode='soft', wavelet_levels=3, wavelet='sym8', rescale_sigma='True')
    x_denoise = x_denoise / max(x_denoise)
    
    # Get the filename without the extension
    filename = os.path.splitext(os.path.basename(file_path))[0]

    # Construct the output file path
    output_file_path = os.path.join(output_folder, filename + ".wav")

    # Save the denoised file
    sf.write(output_file_path, x_denoise, 16000)  # Use soundfile for writing
# Out:
# c:\Users\Nilupulee\AppData\Local\Programs\Python\Python310\lib\site-packages\skimage\restoration\_denoise.py:750: RuntimeWarning: overflow encountered in scalar subtract
#   range_pre = image.max() - image.min()
